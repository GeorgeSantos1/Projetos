# %% [markdown]
# <a href="https://colab.research.google.com/github/GeorgeSantos1/Projetos/blob/main/Sistema_de_Recomendacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Sistema de Recomendação de Livros
#
# Carlos André , George Anderson

# %% [markdown]
# ### Carregando Pacotes
#
# "https://www.kaggle.com/datasets/saurabhbagchi/books-dataset/"

# %%
# Carregando pacotes
import os
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### Importando Bases

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
livros = pd.read_csv("/content/drive/MyDrive/books_data/books.csv", sep=";",
                    error_bad_lines=False, encoding="latin-1")
livros.columns = ['ISBN', 'bookTitle', 'bookAuthor', 'yearOfPublication', 'publisher',
                 'imageUrlS', 'imageUrlM', 'imageUrlL']

notas = pd.read_csv('/content/drive/MyDrive/books_data/ratings.csv', sep=';',
                      error_bad_lines=False, encoding="latin-1")
notas.columns = ['userID', 'ISBN', 'bookRating']

# %% [markdown]
# ### Visualizando Bases

# %%
livros
# Out:
#               ISBN                                          bookTitle  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                   bookAuthor yearOfPublication  \
# 0         Mark P. O. Morford              2002
# 1       Richard Bruce Wright              2001
# 2               Carlo D'Este              1991
# 3           Gina Bari Kolata              1999
# 4            E. J. W. Barber              1999
# ...                      ...               ...
# 271355        Paula Danziger              1988
# 271356            Teri Sloat              1991
# 271357      Christine Wicker              2004
# 271358                 Plato              1996
# 271359   Christopher  Biffle              2000
#
#                                                publisher
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
# [271360 rows x 5 columns]

# %%
notas
# Out:
#          userID         ISBN  bookRating
# 0        276725   034545104X           0
# 1        276726   0155061224           5
# 2        276727   0446520802           0
# 3        276729   052165615X           3
# 4        276729   0521795028           6
# ...         ...          ...         ...
# 1149775  276704   1563526298           9
# 1149776  276706   0679447156           0
# 1149777  276709   0515107662          10
# 1149778  276721   0590442449          10
# 1149779  276723  05162443314           8
#
# [1149780 rows x 3 columns]

# %%
print(livros.shape)
print(notas.shape)
# Out:
# (271360, 8)
# (1149780, 3)

# %% [markdown]
# # Modificando As Bases

# %%
# Retirando Colunas - Sem informações Úteis
livros.drop(['imageUrlS', 'imageUrlM', 'imageUrlL'],axis=1,inplace=True)

# %%
# Retirando Livros ausentes da base "Livros"
notas_novo = notas[notas.ISBN.isin(livros.ISBN)]
notas_novo.shape
# Out:
# (1031136, 3)

# %%
# Retirando Observações com nota = 0
notas_novo = notas_novo[notas_novo.bookRating > 0]
notas_novo.shape
# Out:
# (383842, 3)

# %%
# Filtrando para livros com pelo menos 30 avaliações
contagem = notas_novo["ISBN"].value_counts()
notas_novo  = notas_novo[notas_novo['ISBN'].isin(contagem[contagem >= 30].index)]
livros_novo = livros[livros['ISBN'].isin(contagem[contagem >= 30].index)]

# %%
# Criando Matriz de utilidade: Usuário-Item
notas_matrix = notas_novo.pivot(index='userID', columns='ISBN', values='bookRating')
userID = notas_matrix.index
ISBN = notas_matrix.columns
bookTitle = livros_novo.sort_values("ISBN")
notas_matrix.columns = bookTitle['bookTitle']
notas_matrix.head
# Out:
# (26401, 1130)
# bookTitle  Angelas Ashes  \
# userID
# 9                    NaN
# 16                   NaN
# 26                   NaN
# 39                   NaN
# 42                   NaN
# ...                  ...
# 278843               NaN
# 278844               NaN
# 278846               NaN
# 278851               NaN
# 278854               NaN
#
# bookTitle  Politically Correct Bedtime Stories: Modern Tales for Our Life and Times  \
# userID
# 9                                                        NaN
# 16                                                       NaN
# 26                                                       NaN
# 39                                                       NaN
# 42                                                       NaN
# ...                                                      ...
# 278843                                                   NaN
# 278844                                                   NaN
# 278846                                                   NaN
# 278851                                                   NaN
# 278854                                                   NaN
#
# bookTitle  Once upon a More Enlightened Time: More Politically Correct Bedtime Stories  \
# userID
# 9                                                        NaN
# 16                                                       NaN
# 26                                                       NaN
# 39                                                       NaN
# 42                                                       NaN
# ...                                                      ...
# 278843                                                   NaN
# 278844                                                   NaN
# 278846                                                   NaN
# 278851                                                   NaN
# 278854                                                   NaN
#
# bookTitle  The Death of Vishnu: A Novel  Angels  The Boy Next Door  \
# userID
# 9                                   NaN     NaN                NaN
# 16                                  NaN     NaN                NaN
# 26                                  NaN     NaN                NaN
# 39                                  NaN     NaN                NaN
# 42                                  NaN     NaN                NaN
# ...                                 ...     ...                ...
# 278843                              NaN     NaN                NaN
# 278844                              NaN     NaN                NaN
# 278846                              NaN     NaN                NaN
# 278851                              NaN     NaN                NaN
# 278854                              NaN     NaN                NaN
#
# bookTitle  Men Are from Mars, Women Are from Venus: A Practical Guide for Improving Communication and Getting What You Want in Your Relationships  \
# userID
# 9                                                        NaN
# 16                                                       NaN
# 26                                                       NaN
# 39                                                       NaN
# 42                                                       NaN
# ...                                                      ...
# 278843                                                   NaN
# 278844                                                   NaN
# 278846                                                   NaN
# 278851                                                   NaN
# 278854                                                   NaN
#
# bookTitle  Divine Secrets of the Ya-Ya Sisterhood : A Novel  \
# userID
# 9                                                       NaN
# 16                                                      NaN
# 26                                                      NaN
# 39                                                      NaN
# 42                                                      NaN
# ...                                                     ...
# 278843                                                  9.0
# 278844                                                  NaN
# 278846                                                  NaN
# 278851                                                  NaN
# 278854                                                  NaN
#
# bookTitle  The Poisonwood Bible  The Professor and the Madman  ...  Free  \
# userID                                                         ...
# 9                           NaN                           NaN  ...   NaN
# 16                          NaN                           NaN  ...   NaN
# 26                          NaN                           NaN  ...   NaN
# 39                          NaN                           NaN  ...   NaN
# 42                          NaN                           NaN  ...   NaN
# ...                         ...                           ...  ...   ...
# 278843                      NaN                           NaN  ...   NaN
# 278844                      NaN                           NaN  ...   NaN
# 278846                      NaN                           NaN  ...   NaN
# 278851                      NaN                           NaN  ...   NaN
# 278854                      NaN                           NaN  ...   NaN
#
# bookTitle  Shipping News  \
# userID
# 9                    NaN
# 16                   NaN
# 26                   NaN
# 39                   NaN
# 42                   NaN
# ...                  ...
# 278843               NaN
# 278844               NaN
# 278846               NaN
# 278851               NaN
# 278854               NaN
#
# bookTitle  The Four Agreements: A Practical Guide to Personal Freedom  \
# userID
# 9                                                        NaN
# 16                                                       NaN
# 26                                                       NaN
# 39                                                       NaN
# 42                                                       NaN
# ...                                                      ...
# 278843                                                   NaN
# 278844                                                   NaN
# 278846                                                   NaN
# 278851                                                   NaN
# 278854                                                   NaN
#
# bookTitle  The Time Traveler's Wife (Today Show Book Club #15)  \
# userID
# 9                                                        NaN
# 16                                                       NaN
# 26                                                       NaN
# 39                                                       NaN
# 42                                                       NaN
# ...                                                      ...
# 278843                                                   NaN
# 278844                                                   NaN
# 278846                                                   NaN
# 278851                                                   NaN
# 278854                                                   NaN
#
# bookTitle  Das Parfum: Die Geschichte Eines Morders  Der Vorleser  \
# userID
# 9                                               NaN           NaN
# 16                                              NaN           NaN
# 26                                              NaN           NaN
# 39                                              NaN           NaN
# 42                                              NaN           NaN
# ...                                             ...           ...
# 278843                                          NaN           NaN
# 278844                                          NaN           NaN
# 278846                                          NaN           NaN
# 278851                                          NaN           NaN
# 278854                                          NaN           NaN
#
# bookTitle  Illuminati.  MÃ?Â¶rder ohne Gesicht.  Russendisko.  \
# userID
# 9                  NaN                      NaN           NaN
# 16                 NaN                      NaN           NaN
# 26                 NaN                      NaN           NaN
# 39                 NaN                      NaN           NaN
# 42                 NaN                      NaN           NaN
# ...                ...                      ...           ...
# 278843             NaN                      NaN           NaN
# 278844             NaN                      NaN           NaN
# 278846             NaN                      NaN           NaN
# 278851             NaN                      NaN           NaN
# 278854             NaN                      NaN           NaN
#
# bookTitle  Stupid White Men. Eine Abrechnung mit dem Amerika unter George W. Bush
# userID
# 9                                                        NaN
# 16                                                       NaN
# 26                                                       NaN
# 39                                                       NaN
# 42                                                       NaN
# ...                                                      ...
# 278843                                                   NaN
# 278844                                                   NaN
# 278846                                                   NaN
# 278851                                                   NaN
# 278854                                                   NaN
#
# [26401 rows x 1130 columns]

# %%
# Calculando Similaridade
itembased_cos = cosine_similarity(notas_matrix.T.fillna(0))

# %%
itembased_cos = pd.DataFrame(itembased_cos,columns=bookTitle.bookTitle,index=bookTitle.bookTitle)
itembased_cos
# Out:
# bookTitle                                           Angelas Ashes  \
# bookTitle
# Angelas Ashes                                            1.000000
# Politically Correct Bedtime Stories: Modern Tal...       0.059837
# Once upon a More Enlightened Time: More Politic...       0.000000
# The Death of Vishnu: A Novel                             0.067350
# Angels                                                   0.028577
# ...                                                           ...
# Der Vorleser                                             0.000000
# Illuminati.                                              0.031760
# MÃ?Â¶rder ohne Gesicht.                                  0.026921
# Russendisko.                                             0.026132
# Stupid White Men. Eine Abrechnung mit dem Ameri...       0.031333
#
# bookTitle                                           Politically Correct Bedtime Stories: Modern Tales for Our Life and Times  \
# bookTitle
# Angelas Ashes                                                                                0.059837
# Politically Correct Bedtime Stories: Modern Tal...                                           1.000000
# Once upon a More Enlightened Time: More Politic...                                           0.245434
# The Death of Vishnu: A Novel                                                                 0.011428
# Angels                                                                                       0.015558
# ...                                                                                               ...
# Der Vorleser                                                                                 0.000000
# Illuminati.                                                                                  0.017291
# MÃ?Â¶rder ohne Gesicht.                                                                      0.014656
# Russendisko.                                                                                 0.014226
# Stupid White Men. Eine Abrechnung mit dem Ameri...                                           0.017058
#
# bookTitle                                           Once upon a More Enlightened Time: More Politically Correct Bedtime Stories  \
# bookTitle
# Angelas Ashes                                                                                0.000000
# Politically Correct Bedtime Stories: Modern Tal...                                           0.245434
# Once upon a More Enlightened Time: More Politic...                                           1.000000
# The Death of Vishnu: A Novel                                                                 0.000000
# Angels                                                                                       0.000000
# ...                                                                                               ...
# Der Vorleser                                                                                 0.000000
# Illuminati.                                                                                  0.000000
# MÃ?Â¶rder ohne Gesicht.                                                                      0.000000
# Russendisko.                                                                                 0.000000
# Stupid White Men. Eine Abrechnung mit dem Ameri...                                           0.000000
#
# bookTitle                                           The Death of Vishnu: A Novel  \
# bookTitle
# Angelas Ashes                                                           0.067350
# Politically Correct Bedtime Stories: Modern Tal...                      0.011428
# Once upon a More Enlightened Time: More Politic...                      0.000000
# The Death of Vishnu: A Novel                                            1.000000
# Angels                                                                  0.024334
# ...                                                                          ...
# Der Vorleser                                                            0.000000
# Illuminati.                                                             0.027044
# MÃ?Â¶rder ohne Gesicht.                                                 0.022924
# Russendisko.                                                            0.022251
# Stupid White Men. Eine Abrechnung mit dem Ameri...                      0.026680
#
# bookTitle                                             Angels  \
# bookTitle
# Angelas Ashes                                       0.028577
# Politically Correct Bedtime Stories: Modern Tal...  0.015558
# Once upon a More Enlightened Time: More Politic...  0.000000
# The Death of Vishnu: A Novel                        0.024334
# Angels                                              1.000000
# ...                                                      ...
# Der Vorleser                                        0.000000
# Illuminati.                                         0.036816
# MÃ?Â¶rder ohne Gesicht.                             0.031207
# Russendisko.                                        0.030291
# Stupid White Men. Eine Abrechnung mit dem Ameri...  0.036321
#
# bookTitle                                           The Boy Next Door  \
# bookTitle
# Angelas Ashes                                                0.000000
# Politically Correct Bedtime Stories: Modern Tal...           0.000000
# Once upon a More Enlightened Time: More Politic...           0.023053
# The Death of Vishnu: A Novel                                 0.000000
# Angels                                                       0.036488
# ...                                                               ...
# Der Vorleser                                                 0.000000
# Illuminati.                                                  0.000000
# MÃ?Â¶rder ohne Gesicht.                                      0.000000
# Russendisko.                                                 0.000000
# Stupid White Men. Eine Abrechnung mit dem Ameri...           0.000000
#
# bookTitle                                           Men Are from Mars, Women Are from Venus: A Practical Guide for Improving Communication and Getting What You Want in Your Relationships  \
# bookTitle
# Angelas Ashes                                                                                0.043903
# Politically Correct Bedtime Stories: Modern Tal...                                           0.014222
# Once upon a More Enlightened Time: More Politic...                                           0.000000
# The Death of Vishnu: A Novel                                                                 0.039546
# Angels                                                                                       0.063930
# ...                                                                                               ...
# Der Vorleser                                                                                 0.000000
# Illuminati.                                                                                  0.033655
# MÃ?Â¶rder ohne Gesicht.                                                                      0.028528
# Russendisko.                                                                                 0.027691
# Stupid White Men. Eine Abrechnung mit dem Ameri...                                           0.033203
#
# bookTitle                                           Divine Secrets of the Ya-Ya Sisterhood : A Novel  \
# bookTitle
# Angelas Ashes                                                                                    0.0
# Politically Correct Bedtime Stories: Modern Tal...                                               0.0
# Once upon a More Enlightened Time: More Politic...                                               0.0
# The Death of Vishnu: A Novel                                                                     0.0
# Angels                                                                                           0.0
# ...                                                                                              ...
# Der Vorleser                                                                                     0.0
# Illuminati.                                                                                      0.0
# MÃ?Â¶rder ohne Gesicht.                                                                          0.0
# Russendisko.                                                                                     0.0
# Stupid White Men. Eine Abrechnung mit dem Ameri...                                               0.0
#
# bookTitle                                           The Poisonwood Bible  \
# bookTitle
# Angelas Ashes                                                   0.020793
# Politically Correct Bedtime Stories: Modern Tal...              0.024904
# Once upon a More Enlightened Time: More Politic...              0.017989
# The Death of Vishnu: A Novel                                    0.017705
# Angels                                                          0.024103
# ...                                                                  ...
# Der Vorleser                                                    0.000000
# Illuminati.                                                     0.026788
# MÃ?Â¶rder ohne Gesicht.                                         0.022706
# Russendisko.                                                    0.022040
# Stupid White Men. Eine Abrechnung mit dem Ameri...              0.026427
#
# bookTitle                                           The Professor and the Madman  \
# bookTitle
# Angelas Ashes                                                           0.000000
# Politically Correct Bedtime Stories: Modern Tal...                      0.000000
# Once upon a More Enlightened Time: More Politic...                      0.000000
# The Death of Vishnu: A Novel                                            0.057815
# Angels                                                                  0.000000
# ...                                                                          ...
# Der Vorleser                                                            0.000000
# Illuminati.                                                             0.000000
# MÃ?Â¶rder ohne Gesicht.                                                 0.000000
# Russendisko.                                                            0.000000
# Stupid White Men. Eine Abrechnung mit dem Ameri...                      0.000000
#
# bookTitle                                           ...      Free  \
# bookTitle                                           ...
# Angelas Ashes                                       ...  0.020425
# Politically Correct Bedtime Stories: Modern Tal...  ...  0.011120
# Once upon a More Enlightened Time: More Politic...  ...  0.000000
# The Death of Vishnu: A Novel                        ...  0.017392
# Angels                                              ...  0.023676
# ...                                                 ...       ...
# Der Vorleser                                        ...  0.000000
# Illuminati.                                         ...  0.026314
# MÃ?Â¶rder ohne Gesicht.                             ...  0.022304
# Russendisko.                                        ...  0.021650
# Stupid White Men. Eine Abrechnung mit dem Ameri...  ...  0.025959
#
# bookTitle                                           Shipping News  \
# bookTitle
# Angelas Ashes                                            0.056499
# Politically Correct Bedtime Stories: Modern Tal...       0.014474
# Once upon a More Enlightened Time: More Politic...       0.000000
# The Death of Vishnu: A Novel                             0.022639
# Angels                                                   0.050082
# ...                                                           ...
# Der Vorleser                                             0.000000
# Illuminati.                                              0.034253
# MÃ?Â¶rder ohne Gesicht.                                  0.029034
# Russendisko.                                             0.028182
# Stupid White Men. Eine Abrechnung mit dem Ameri...       0.033792
#
# bookTitle                                           The Four Agreements: A Practical Guide to Personal Freedom  \
# bookTitle
# Angelas Ashes                                                                                0.015513
# Politically Correct Bedtime Stories: Modern Tal...                                           0.000000
# Once upon a More Enlightened Time: More Politic...                                           0.000000
# The Death of Vishnu: A Novel                                                                 0.015097
# Angels                                                                                       0.000000
# ...                                                                                               ...
# Der Vorleser                                                                                 0.000000
# Illuminati.                                                                                  0.000000
# MÃ?Â¶rder ohne Gesicht.                                                                      0.000000
# Russendisko.                                                                                 0.000000
# Stupid White Men. Eine Abrechnung mit dem Ameri...                                           0.000000
#
# bookTitle                                           The Time Traveler's Wife (Today Show Book Club #15)  \
# bookTitle
# Angelas Ashes                                                                                0.029615
# Politically Correct Bedtime Stories: Modern Tal...                                           0.016122
# Once upon a More Enlightened Time: More Politic...                                           0.000000
# The Death of Vishnu: A Novel                                                                 0.025217
# Angels                                                                                       0.034329
# ...                                                                                               ...
# Der Vorleser                                                                                 0.000000
# Illuminati.                                                                                  0.038152
# MÃ?Â¶rder ohne Gesicht.                                                                      0.032339
# Russendisko.                                                                                 0.031391
# Stupid White Men. Eine Abrechnung mit dem Ameri...                                           0.037639
#
# bookTitle                                           Das Parfum: Die Geschichte Eines Morders  \
# bookTitle
# Angelas Ashes                                                                       0.000000
# Politically Correct Bedtime Stories: Modern Tal...                                  0.000000
# Once upon a More Enlightened Time: More Politic...                                  0.000000
# The Death of Vishnu: A Novel                                                        0.000000
# Angels                                                                              0.000000
# ...                                                                                      ...
# Der Vorleser                                                                        0.066448
# Illuminati.                                                                         0.076322
# MÃ?Â¶rder ohne Gesicht.                                                             0.000000
# Russendisko.                                                                        0.000000
# Stupid White Men. Eine Abrechnung mit dem Ameri...                                  0.035433
#
# bookTitle                                           Der Vorleser  Illuminati.  \
# bookTitle
# Angelas Ashes                                           0.000000     0.031760
# Politically Correct Bedtime Stories: Modern Tal...      0.000000     0.017291
# Once upon a More Enlightened Time: More Politic...      0.000000     0.000000
# The Death of Vishnu: A Novel                            0.000000     0.027044
# Angels                                                  0.000000     0.036816
# ...                                                          ...          ...
# Der Vorleser                                            1.000000     0.030943
# Illuminati.                                             0.030943     1.000000
# MÃ?Â¶rder ohne Gesicht.                                 0.000000     0.078036
# Russendisko.                                            0.028057     0.050979
# Stupid White Men. Eine Abrechnung mit dem Ameri...      0.048455     0.040366
#
# bookTitle                                           MÃ?Â¶rder ohne Gesicht.  \
# bookTitle
# Angelas Ashes                                                      0.026921
# Politically Correct Bedtime Stories: Modern Tal...                 0.014656
# Once upon a More Enlightened Time: More Politic...                 0.000000
# The Death of Vishnu: A Novel                                       0.022924
# Angels                                                             0.031207
# ...                                                                     ...
# Der Vorleser                                                       0.000000
# Illuminati.                                                        0.078036
# MÃ?Â¶rder ohne Gesicht.                                            1.000000
# Russendisko.                                                       0.028536
# Stupid White Men. Eine Abrechnung mit dem Ameri...                 0.054175
#
# bookTitle                                           Russendisko.  \
# bookTitle
# Angelas Ashes                                           0.026132
# Politically Correct Bedtime Stories: Modern Tal...      0.014226
# Once upon a More Enlightened Time: More Politic...      0.000000
# The Death of Vishnu: A Novel                            0.022251
# Angels                                                  0.030291
# ...                                                          ...
# Der Vorleser                                            0.028057
# Illuminati.                                             0.050979
# MÃ?Â¶rder ohne Gesicht.                                 0.028536
# Russendisko.                                            1.000000
# Stupid White Men. Eine Abrechnung mit dem Ameri...      0.117034
#
# bookTitle                                           Stupid White Men. Eine Abrechnung mit dem Amerika unter George W. Bush
# bookTitle
# Angelas Ashes                                                                                0.031333
# Politically Correct Bedtime Stories: Modern Tal...                                           0.017058
# Once upon a More Enlightened Time: More Politic...                                           0.000000
# The Death of Vishnu: A Novel                                                                 0.026680
# Angels                                                                                       0.036321
# ...                                                                                               ...
# Der Vorleser                                                                                 0.048455
# Illuminati.                                                                                  0.040366
# MÃ?Â¶rder ohne Gesicht.                                                                      0.054175
# Russendisko.                                                                                 0.117034
# Stupid White Men. Eine Abrechnung mit dem Ameri...                                           1.000000
#
# [1130 rows x 1130 columns]

# %%
# Similaridade por cosseno - Baseado em Items
def get_sim_itembased(book):
  result = itembased_cos[book].sort_values(ascending=False)[1:6]
  return result

# %% [markdown]
# ### Gerando recomendações para alguns livros

# %%
get_sim_itembased("Animal Farm")
# Out:
# bookTitle
# 1984                                                         0.148712
# The Green Mile: The Mouse on the Mile (Green Mile Series)    0.120728
# Lord of the Flies                                            0.109087
# The Green Mile: Coffey's Hands (Green Mile Series)           0.088075
# The Two Dead Girls (Green Mile Series)                       0.078501
# Name: Animal Farm, dtype: float64

# %%
get_sim_itembased("Fight Club")
# Out:
# bookTitle
# Invisible Monsters                           0.265240
# Survivor : A Novel                           0.237804
# Choke                                        0.135046
# Lullaby: A Novel                             0.129517
# Wizard and Glass (The Dark Tower, Book 4)    0.098695
# Name: Fight Club, dtype: float64

# %%
get_sim_itembased("The Hobbit : The Enchanting Prelude to The Lord of the Rings")
# Out:
# bookTitle
# The Return of the King (The Lord of the Rings, Part 3)               0.238425
# The Two Towers (The Lord of the Rings, Part 2)                       0.226759
# The Fellowship of the Ring (The Lord of the Rings, Part 1)           0.221640
# The Silmarillion                                                     0.061428
# Left Behind: A Novel of the Earth's Last Days (Left Behind No. 1)    0.060884
# Name: The Hobbit : The Enchanting Prelude to The Lord of the Rings, dtype: float64

# %%
get_sim_itembased("The Green Mile")
# Out:
# bookTitle
# Dreamcatcher                                  0.116914
# It                                            0.113535
# The Dark Half                                 0.093562
# Firestarter                                   0.092849
# Needful Things: The Last Castle Rock Story    0.090285
# Name: The Green Mile, dtype: float64

# %% [markdown]
# ### Gerando Recomendações para um indivíduo em específico

# %%
user_id = 11676

user_id_read = pd.DataFrame(notas_matrix.T[user_id].dropna(axis=0,how="all"))\
                    .sort_values(by=[user_id],ascending=False)\
                    .reset_index()\
                    .rename(columns={user_id:"ratings"})

user_id_read
# Out:
#                                              bookTitle  ratings
# 0                                        The Outsiders     10.0
# 1                                            Bleachers     10.0
# 2                                   The Cat in the Hat     10.0
# 3                                        Roses Are Red     10.0
# 4                                        Cat and Mouse     10.0
# ..                                                 ...      ...
# 636                                The Horse Whisperer      1.0
# 637  She's Come Undone (Oprah's Book Club (Paperback))      1.0
# 638                                           The Firm      1.0
# 639                                   The Lovely Bones      1.0
# 640                                           Jackdaws      1.0
#
# [641 rows x 2 columns]

# %%
book_picked = "Pride and Prejudice"

# %%
# Similaridade entre livros lidos pelo usuário e 'book_picked'
book_picked_simscore = itembased_cos[book_picked].reset_index()\
                                                 .rename(columns={book_picked:"similarity_score"})

# %%
# Similaridade entre livros lidos pelo usuário e 'book_picked'
book_user_id_read_simscore = pd.merge(left=user_id_read,
         right=book_picked_simscore,
         on="bookTitle",
         how="inner")\
  .sort_values("similarity_score",ascending=False)[1:6]

book_user_id_read_simscore
# Out:
#                                              bookTitle  ratings  \
# 339  Nicolae: The Rise of Antichrist (Left Behind N...      8.0
# 245                                Amsterdam : A Novel      9.0
# 440                                            Killjoy      8.0
# 26                                 The English Patient     10.0
# 399                                 I'll Be Seeing You      8.0
#
#      similarity_score
# 339          0.084448
# 245          0.082439
# 440          0.081008
# 26           0.079201
# 399          0.077192

# %%
predicted_rating = round(np.average(book_user_id_watched_simscore["ratings"],
                                    weights=book_user_id_watched_simscore["similarity_score"]),4)

# %%
print(f'A nota prevista para {book_picked} pelo usuário {user_id} é {predicted_rating}')
# Out:
# A nota prevista para Pride and Prejudice pelo usuário 11676 é 8.5957

# %% [markdown]
# ### Sistema de Recomendação para um usuário específico

# %%
def item_based_rec(user_id, number_of_similar_items = 5,recomendations=5):
  import operator
  # Livros não lidos pelo usuário
  userid_unread = pd.DataFrame(notas_matrix.T[user_id].isna()).reset_index()
  userid_unread = userid_unread[userid_unread[user_id]==True]["bookTitle"].tolist()

  # Livros Lidos
  user_id_watched = pd.DataFrame(notas_matrix.T[user_id].dropna(axis=0,how="all"))\
                    .sort_values(by=[user_id],ascending=False)\
                    .reset_index()\
                    .rename(columns={user_id:"ratings"})

  rating_prediction = {}

  # Loop pelos livros não lidos
  for book_picked in userid_unread:
    book_picked_simscore = itembased_cos[book_picked].reset_index()\
                                                 .rename(columns={book_picked:"similarity_score"})

    book_picked_simscore = book_picked_simscore.loc[:,~book_picked_simscore.columns.duplicated()].copy()

    book_user_id_read_simscore = pd.merge(left=user_id_watched,
         right=book_picked_simscore,
         on="bookTitle",
         how="inner")\
         .sort_values("similarity_score",ascending=False)[1:number_of_similar_items+1]


    predicted_rating = round(np.average(book_user_id_read_simscore["ratings"],
                                    weights=book_user_id_read_simscore["similarity_score"]),4)

    rating_prediction[book_picked] = predicted_rating


  return sorted(rating_prediction.items(),key=operator.itemgetter(1),reverse=True)[:recomendations]

# %%
item_based_rec(user_id=11676,number_of_similar_items = 10)
# Out:
# [('Key of Light (Key Trilogy (Paperback))', 9.3979),
#  ('The Princess Diaries', 9.2553),
#  ('Desecration: Antichrist Takes the Throne (Left Behind No. 9)', 9.2427),
#  ('Harry Potter and the Order of the Phoenix (Book 5)', 9.1836),
#  ('Tears of the Moon (Irish Trilogy)', 9.1784)]
